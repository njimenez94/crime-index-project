# %%
import pandas as pd
import os

pd.set_option('display.max_columns', None)

# %run ../scripts/config.py

# %%
paths = setup_paths()

# %%
file = os.path.join(paths['data_processed'], 'data_processed.csv')

data = pd.read_csv(file)

# %%
data.head()
# Out:
#   continent           region       country  year  criminality  \
# 0      Asia     Western Asia        Turkey  2021         6.89
# 1    Africa      West Africa    Cabo Verde  2021         4.04
# 2    Africa  Southern Africa  South Africa  2021         6.63
# 3  Americas    South America      Colombia  2021         7.66
# 4  Americas    South America          Peru  2021         6.35
#
#    criminal_markets  human_trafficking  human_smuggling  arms_trafficking  \
# 0               6.4                7.0              9.0               9.0
# 1               3.7                4.5              2.0               2.5
# 2               6.0                4.5              4.0               8.0
# 3               7.2                7.5              7.0               8.0
# 4               6.2                7.0              6.0               5.5
#
#    flora_crimes  fauna_crimes  non_renewable_resource_crimes  heroin_trade  \
# ...
